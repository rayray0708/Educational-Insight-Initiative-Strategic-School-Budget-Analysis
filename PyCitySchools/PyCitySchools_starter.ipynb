# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load (Remember to Change These)
school_data_to_load = Path("Resources/schools_complete.csv")
student_data_to_load = Path("Resources/students_complete.csv")

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete
# Out:
#        Student ID     student_name gender  year         school_name  \
# 0               0     Paul Bradley      M     9   Huang High School
# 1               1     Victor Smith      M    12   Huang High School
# 2               2  Kevin Rodriguez      M    12   Huang High School
# 3               3    Richard Scott      M    12   Huang High School
# 4               4       Bonnie Ray      F     9   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F    12  Thomas High School
# 39166       39166        Dawn Bell      F    10  Thomas High School
# 39167       39167   Rebecca Tanner      F     9  Thomas High School
# 39168       39168     Desiree Kidd      F    10  Thomas High School
# 39169       39169  Carolyn Jackson      F    11  Thomas High School
#
#        reading_score  maths_score  School ID         type  size   budget
# 0                 96           94          0   Government  2917  1910635
# ...

# %% [markdown]
# ## Local Government Area Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average maths score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing maths score (50 or greater)
#
# * Calculate the percentage of students with a passing reading score (50 or greater)
#
# * Calculate the percentage of students who passed maths **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#calculate number of schools first by using the unique function, and len() function
total_schools = len(school_data_complete["school_name"].unique())
# total_schools

#calculate the number of students
total_students = school_data_complete["student_name"].count()
# total_students

#sum all the unique budgets 
total_budget = school_data_complete["budget"].unique().sum()
# total_budget

#find mean of maths score
average_maths = school_data_complete["maths_score"].mean()
# find average reading score across all schools
average_reading = school_data_complete["reading_score"].mean()
# average_reading


# Calculate the percentage of students with a passing maths score (50 or greater)
## Use loc to filter out students who achieved lower than 50,
##to perform a function on this condition, put it inside round brackets
passed_maths = (school_data_complete["maths_score"] >= 50).sum() 

## Divide sum of those who passed maths by total number of students
percentage_passed_maths = passed_maths/total_students*100
percentage_passed_maths

# Calculate the percentage of students with a passing reading score (50 or greater)
## Use loc to filter out students who achieved lower than 50,
##to perform a function on this condition, put it inside round brackets
passed_reading = (school_data_complete["reading_score"] >= 50).sum()
passed_reading

## Divide sum of those who passed reading by total number of students
percentage_passed_reading = passed_reading/total_students*100
percentage_passed_reading

# Calculate the percentage of students who passed maths and reading (% Overall Passing)
passed_overall = len(school_data_complete.loc[(school_data_complete["maths_score"] >= 50)
                                          &(school_data_complete["reading_score"] >= 50),"student_name"])
passed_overall

## Divide sum of those who passed both maths AND reading by total number of students
percentage_passed_overall = passed_overall/total_students*100
percentage_passed_overall
                                           
# Create a dataframe to hold the above results

area_summary = pd.DataFrame({"Total Schools": [total_schools],
                                    "Total Students": total_students,
                                    "Total Budget": total_budget,
                                    "Average Maths Score": average_maths,
                                    "Average Reading Score": average_reading,
                                     "% Passing Maths": percentage_passed_maths,
                                     "% Passing Reading": percentage_passed_reading,
                                     "% Overall Passing": percentage_passed_overall})
area_summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Maths Score  \
# 0             15           39170      24649428            70.338192
#
#    Average Reading Score  % Passing Maths  % Passing Reading  \
# 0              69.980138        86.078632          84.426857
#
#    % Overall Passing
# 0          72.808272

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarises key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed maths **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#set index to school name 
school_type = school_data.set_index(["school_name"])["type"]

#creating separate dataframes for each of the conditions
#will use these dataframes to find the total of students who passed only maths, only reading and both
school_passing_maths = school_data_complete[(school_data_complete["maths_score"] >= 50)]
school_passing_reading = school_data_complete[(school_data_complete["reading_score"] >= 50)]
school_passing_maths_reading = school_data_complete[(school_data_complete["reading_score"] >= 50) & (school_data_complete["maths_score"] >= 50)]

#group original dataframe by school name
grouped_school_df = school_data_complete.groupby(["school_name"])

grouped_total_students=grouped_school_df["student_name"].count()
grouped_total_students
grouped_total_school_budget=grouped_school_df["budget"].mean()
# grouped_total_school_budget
grouped_per_student= grouped_total_school_budget/grouped_total_students
# grouped_per_student
grouped_average_maths = grouped_school_df["maths_score"].mean()
# grouped_average_maths_reading

grouped_average_reading = grouped_school_df["reading_score"].mean()

# percentage of passed maths = number of students who passed maths at each school/total 
# number of students at each school and time by 100
#we can do calculations with columns in different dataframes here because they're both grouped by school_name
#i.e., share the same index (i.e., school_name) and both have the same length
percentage_passed_maths = school_passing_maths.groupby(["school_name"]).count()["student_name"]/grouped_total_students*100
percentage_passed_maths


percentage_passed_reading = school_passing_reading.groupby(["school_name"]).count()["student_name"]/grouped_total_students*100
percentage_passed_reading

percentage_passed_overall = school_passing_maths_reading.groupby(["school_name"]).count()["student_name"]/grouped_total_students*100
percentage_passed_overall

#create a dataframe to hold all of the found values
school_summary= pd.DataFrame({"School Type": school_type,
                              "Total Students": grouped_total_students,
                              "Total School Budget": grouped_total_school_budget,
                              "Per Student Budget": grouped_per_student,
                              "Average Math Score": grouped_average_maths,
                              "Average Reading Score": grouped_average_reading,
                              "% Passing Math": percentage_passed_maths,
                              "% Passing Reading": percentage_passed_reading,
                              "% Overall Passing": percentage_passed_overall})
school_summary

#mapping for column Total School Budget 
school_summary["Total School Budget"] = school_summary["Total School Budget"].map("${:,}".format)
school_summary

#mapping for column Per Student Budget
school_summary["Per Student Budget"] = school_summary["Per Student Budget"].map("${:}".format)
school_summary
# Out:
#                        School Type  Total Students Total School Budget  \
# school_name
# Bailey High School      Government            4976        $3,124,928.0
# Cabrera High School    Independent            1858        $1,081,356.0
# Figueroa High School    Government            2949        $1,884,411.0
# Ford High School        Government            2739        $1,763,916.0
# Griffin High School    Independent            1468          $917,500.0
# Hernandez High School   Government            4635        $3,022,020.0
# Holden High School     Independent             427          $248,087.0
# Huang High School       Government            2917        $1,910,635.0
# Johnson High School     Government            4761        $3,094,650.0
# Pena High School       Independent             962          $585,858.0
# Rodriguez High School   Government            3999        $2,547,363.0
# Shelton High School    Independent            1761        $1,056,600.0
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
top_schools = school_summary.sort_values("% Overall Passing", ascending=False).head()
top_schools
# Out:
#                        School Type  Total Students Total School Budget  \
# school_name
# Griffin High School    Independent            1468          $917,500.0
# Cabrera High School    Independent            1858        $1,081,356.0
# Bailey High School      Government            4976        $3,124,928.0
# Wright High School     Independent            1800        $1,049,400.0
# Rodriguez High School   Government            3999        $2,547,363.0
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Griffin High School               $625.0           71.788147
# Cabrera High School               $582.0           71.657158
# Bailey High School                $628.0           72.352894
# Wright High School                $583.0           72.047222
# Rodriguez High School             $637.0           72.047762
#
#                        Average Reading Score  % Passing Math  \
# school_name
# Griffin High School                71.245232       91.212534
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_schools = school_summary.sort_values("% Overall Passing").head()
bottom_schools
# Out:
#                        School Type  Total Students Total School Budget  \
# school_name
# Hernandez High School   Government            4635        $3,022,020.0
# Huang High School       Government            2917        $1,910,635.0
# Johnson High School     Government            4761        $3,094,650.0
# Wilson High School     Independent            2283        $1,319,574.0
# Ford High School        Government            2739        $1,763,916.0
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Hernandez High School             $652.0           68.874865
# Huang High School                 $655.0           68.935207
# Johnson High School               $650.0           68.843100
# Wilson High School                $578.0           69.170828
# Ford High School                  $644.0           69.091274
#
#                        Average Reading Score  % Passing Math  \
# school_name
# Hernandez High School              69.186408       80.949299
# ...

# %% [markdown]
# ## Maths Scores by Year

# %% [markdown]
# * Create a table that lists the average maths score for students of each year level (9, 10, 11, 12) at each school.
#
#   * Create a pandas series for each year. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
#create a dataframe for year 9 values using loc[], group them by school_name and calculate the mean score for each school
year_9 = school_data_complete.loc[school_data_complete["year"]== 9].groupby(["school_name"]).mean()["maths_score"]
year_9
# #create a dataframe for year 10 values using loc[], group them by school_name and calculate the mean score for each school
year_10 = school_data_complete.loc[school_data_complete["year"]== 10].groupby(["school_name"]).mean()["maths_score"]
# year_10
# #create a dataframe for year 11 values using loc[], group them by school_name and calculate the mean score for each school
year_11 = school_data_complete.loc[school_data_complete["year"]== 11].groupby(["school_name"]).mean()["maths_score"]
# year_11 
# #create a dataframe for year 12 values using loc[], group them by school_name and calculate the mean score for each school
year_12 = school_data_complete.loc[school_data_complete["year"]== 12].groupby(["school_name"]).mean()["maths_score"]

#create a dataframe to hold new values
maths_scores_by_year = pd.DataFrame ({"Year 9": year_9,
                                  "Year 10": year_10,
                                  "Year 11": year_11,
                                  "Year 12": year_12})
maths_scores_by_year
# Out:
# /var/folders/tz/ngjhtdzj6d71nrpqsl3hy_m00000gn/T/ipykernel_77125/851669040.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   year_9 = school_data_complete.loc[school_data_complete["year"]== 9].groupby(["school_name"]).mean()["maths_score"]
# /var/folders/tz/ngjhtdzj6d71nrpqsl3hy_m00000gn/T/ipykernel_77125/851669040.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   year_10 = school_data_complete.loc[school_data_complete["year"]== 10].groupby(["school_name"]).mean()["maths_score"]
# ...

# %% [markdown]
# ## Reading Score by Year

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
#exact same logic as calculating math scores by year
year_9_read = school_data_complete.loc[school_data_complete["year"]== 9].groupby(["school_name"]).mean()["reading_score"]
year_9
year_10_read = school_data_complete.loc[school_data_complete["year"]== 10].groupby(["school_name"]).mean()["reading_score"]
year_10
year_11_read = school_data_complete.loc[school_data_complete["year"]== 11].groupby(["school_name"]).mean()["reading_score"]
year_11 
year_12_read = school_data_complete.loc[school_data_complete["year"]== 12].groupby(["school_name"]).mean()["reading_score"]

reading_scores_by_year = pd.DataFrame ({"Year 9": year_9_read,
                                  "Year 10": year_10_read,
                                  "Year 11": year_11_read,
                                  "Year 12": year_12_read})
reading_scores_by_year
# Out:
# /var/folders/tz/ngjhtdzj6d71nrpqsl3hy_m00000gn/T/ipykernel_77125/1220125722.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   year_9_read = school_data_complete.loc[school_data_complete["year"]== 9].groupby(["school_name"]).mean()["reading_score"]
# /var/folders/tz/ngjhtdzj6d71nrpqsl3hy_m00000gn/T/ipykernel_77125/1220125722.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   year_10_read = school_data_complete.loc[school_data_complete["year"]== 10].groupby(["school_name"]).mean()["reading_score"]
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
#check data type
school_summary.dtypes
# Out:
# School Type               object
# Total Students             int64
# Total School Budget       object
# Per Student Budget        object
# Average Math Score       float64
# Average Reading Score    float64
# % Passing Math           float64
# % Passing Reading        float64
# % Overall Passing        float64
# dtype: object

# %%
#"Average Math Score" was initially a category value so needed to be changed to string and then back to float
school_summary["Average Math Score"] = school_summary["Average Math Score"].astype(str)
school_summary["Average Math Score"] = school_summary["Average Math Score"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[218], line 2
#       1 school_summary["Average Math Score"] = school_summary["Average Math Score"].astype(str)
# ----> 2 school_summary["Average Math Score"] = school_summary["Average Math Score"].astype(float)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
#create bins and bin names
bins = [0,585,630,645,680]
group_names = ["<$585", "$585-630", "$630-645", "$645-680"]

#binning based on the grouped_per_student column because values in the "Per Student Budget" column are strings
#include 0
school_summary["Spending Ranges(Per Student)"] = pd.cut(grouped_per_student, 
                                               bins, labels=group_names, include_lowest=True)

#create a dataframe that is grouped by "Spending Ranges (Per Student)", 
#calculate mean for each bin and drop the "Total Students" column
spending_summary = school_summary.groupby("Spending Ranges(Per Student)").mean().drop("Total Students", axis=1)
spending_summary
# Out:
# /var/folders/tz/ngjhtdzj6d71nrpqsl3hy_m00000gn/T/ipykernel_73747/3740881622.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   spending_summary = school_summary.groupby("Spending Ranges(Per Student)").mean().drop("Total Students", axis=1)
#                               Average Math Score  Average Reading Score  \
# Spending Ranges(Per Student)
# <$585                                  71.364587              70.716577
# $585-630                               72.065868              71.031297
# $630-645                               69.854807              69.838814
# $645-680                               68.884391              69.045403
#
#                               % Passing Math  % Passing Reading  \
# Spending Ranges(Per Student)
# ...

# %%
# Out:
#                                Average Maths Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                        71.36                  70.72
# $585-630                                     72.07                  71.03
# $630-645                                     69.85                  69.84
# $645-680                                     68.88                  69.05
#
#                                % Passing Maths  % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                                    88.84              86.39
# $585-630                                 91.52              87.29
# $630-645                                 84.69              83.76
# $645-680                                 81.57              81.77
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$585                                      76.72
# $585-630                                   79.88
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
bins_size = [0,1000,2000,5000]
group_names_size = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

#binning based on "Total students"
#include 0
school_summary["School Size"] = pd.cut(school_summary["Total Students"], 
                                               bins_size, labels=group_names_size, include_lowest=True)
##create a dataframe that is grouped by "School size", 
#calculate mean for each bin and drop the "Total Students" column
size_summary = school_summary.groupby("School Size").mean().drop("Total Students", axis=1)
size_summary
# Out:
# /var/folders/tz/ngjhtdzj6d71nrpqsl3hy_m00000gn/T/ipykernel_73747/3697838707.py:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   size_summary = school_summary.groupby("School Size").mean().drop("Total Students", axis=1)
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                72.335748              71.636864       90.806867
# Medium (1000-2000)           71.421650              70.720164       89.846560
# Large (2000-5000)            69.751809              69.576052       84.252804
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               87.557513          79.066348
# Medium (1000-2000)          86.714149          78.039785
# ...

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
#group by "School Type", calculate mean for each type and drop the "Total Students" column
type_summary = school_summary.groupby("School Type").mean().drop("Total Students", axis=1)
type_summary
# Out:
# /var/folders/tz/ngjhtdzj6d71nrpqsl3hy_m00000gn/T/ipykernel_73747/2102172235.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   type_summary = school_summary.groupby("School Type").mean().drop("Total Students", axis=1)
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Government            69.834806              69.675929       84.462375
# Independent           71.368822              70.718933       89.204043
#
#              % Passing Reading  % Overall Passing
# School Type
# Government           83.587562          70.698993
# Independent          86.247789          76.973340
